# %%
import numpy as np
import pandas as pd
import datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
np.random.seed(402)

# %%
# %%time
df_train = pd.read_csv('../data/train.csv')
df_test = pd.read_csv('../data/test.csv')
df_hist_trans = pd.read_csv('../data/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../data/new_merchant_transactions.csv')
# Out:
# CPU times: user 1min 3s, sys: 18.8 s, total: 1min 22s
# Wall time: 1min 26s

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
# %%time
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']
# Out:
# CPU times: user 25.1 s, sys: 4.48 s, total: 29.6 s
# Wall time: 29.7 s

# %%
# %%time
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# CPU times: user 2min 8s, sys: 17.4 s, total: 2min 26s
# Wall time: 2min 29s

# %%
# %%time
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# CPU times: user 13.2 s, sys: 1.26 s, total: 14.5 s
# Wall time: 14.7 s

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                      -0.550160                      -0.592993
# 1                      -0.550160                      -0.606486
# 2                      -0.549015                      -0.592993
# 3                      -0.556518                      -0.604559
# 4                      -0.555446                      -0.588217
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           252.0
# 1                           282.0
# 2                           253.0
# 3                           263.0
# 4                           253.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
# %%time
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)
# Out:
# CPU times: user 494 ms, sys: 306 ms, total: 800 ms
# Wall time: 825 ms

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','target','outliers']]
target = df_train['target']
del df_train['target']

# %%
# %%time
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.01,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": -1,
         "random_state": 402}
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=402)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.6654	valid_1's rmse: 3.72096
# [200]	training's rmse: 3.58883	valid_1's rmse: 3.68958
# [300]	training's rmse: 3.54103	valid_1's rmse: 3.67529
# [400]	training's rmse: 3.50343	valid_1's rmse: 3.66739
# [500]	training's rmse: 3.47382	valid_1's rmse: 3.66234
# [600]	training's rmse: 3.4493	valid_1's rmse: 3.65847
# [700]	training's rmse: 3.42624	valid_1's rmse: 3.65632
# [800]	training's rmse: 3.4048	valid_1's rmse: 3.6549
# [900]	training's rmse: 3.38582	valid_1's rmse: 3.65356
# [1000]	training's rmse: 3.36824	valid_1's rmse: 3.65314
# [1100]	training's rmse: 3.3512	valid_1's rmse: 3.65201
# [1200]	training's rmse: 3.33543	valid_1's rmse: 3.65159
# [1300]	training's rmse: 3.31915	valid_1's rmse: 3.65147
# [1400]	training's rmse: 3.30429	valid_1's rmse: 3.65087
# [1500]	training's rmse: 3.28977	valid_1's rmse: 3.65032
# [1600]	training's rmse: 3.27627	valid_1's rmse: 3.65043
# [1700]	training's rmse: 3.26295	valid_1's rmse: 3.65063
# Early stopping, best iteration is:
# [1564]	training's rmse: 3.2814	valid_1's rmse: 3.65022
# fold 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66302	valid_1's rmse: 3.72346
# [200]	training's rmse: 3.58479	valid_1's rmse: 3.69375
# [300]	training's rmse: 3.5377	valid_1's rmse: 3.68286
# [400]	training's rmse: 3.50096	valid_1's rmse: 3.67633
# [500]	training's rmse: 3.47226	valid_1's rmse: 3.67203
# [600]	training's rmse: 3.44749	valid_1's rmse: 3.66927
# [700]	training's rmse: 3.42631	valid_1's rmse: 3.66659
# [800]	training's rmse: 3.40699	valid_1's rmse: 3.66507
# [900]	training's rmse: 3.38797	valid_1's rmse: 3.66433
# [1000]	training's rmse: 3.37122	valid_1's rmse: 3.66403
# [1100]	training's rmse: 3.35474	valid_1's rmse: 3.66377
# [1200]	training's rmse: 3.33775	valid_1's rmse: 3.66284
# [1300]	training's rmse: 3.32198	valid_1's rmse: 3.66324
# Early stopping, best iteration is:
# [1187]	training's rmse: 3.33981	valid_1's rmse: 3.66276
# fold 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66881	valid_1's rmse: 3.71686
# [200]	training's rmse: 3.59297	valid_1's rmse: 3.68553
# [300]	training's rmse: 3.54579	valid_1's rmse: 3.67176
# [400]	training's rmse: 3.50973	valid_1's rmse: 3.66414
# [500]	training's rmse: 3.48149	valid_1's rmse: 3.66019
# [600]	training's rmse: 3.45644	valid_1's rmse: 3.65743
# [700]	training's rmse: 3.43498	valid_1's rmse: 3.65638
# [800]	training's rmse: 3.41516	valid_1's rmse: 3.65533
# [900]	training's rmse: 3.39606	valid_1's rmse: 3.65426
# [1000]	training's rmse: 3.37898	valid_1's rmse: 3.65335
# [1100]	training's rmse: 3.36253	valid_1's rmse: 3.653
# [1200]	training's rmse: 3.34697	valid_1's rmse: 3.65305
# [1300]	training's rmse: 3.33121	valid_1's rmse: 3.65276
# [1400]	training's rmse: 3.3153	valid_1's rmse: 3.65283
# [1500]	training's rmse: 3.30035	valid_1's rmse: 3.65301
# Early stopping, best iteration is:
# [1390]	training's rmse: 3.31701	valid_1's rmse: 3.65258
# fold 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66448	valid_1's rmse: 3.71649
# [200]	training's rmse: 3.58599	valid_1's rmse: 3.68668
# [300]	training's rmse: 3.53795	valid_1's rmse: 3.6749
# [400]	training's rmse: 3.50247	valid_1's rmse: 3.66866
# [500]	training's rmse: 3.47242	valid_1's rmse: 3.66561
# [600]	training's rmse: 3.44742	valid_1's rmse: 3.6634
# [700]	training's rmse: 3.42519	valid_1's rmse: 3.66181
# [800]	training's rmse: 3.40523	valid_1's rmse: 3.66122
# [900]	training's rmse: 3.38668	valid_1's rmse: 3.66076
# [1000]	training's rmse: 3.36798	valid_1's rmse: 3.66062
# [1100]	training's rmse: 3.35095	valid_1's rmse: 3.6605
# [1200]	training's rmse: 3.33494	valid_1's rmse: 3.66073
# Early stopping, best iteration is:
# [1052]	training's rmse: 3.35871	valid_1's rmse: 3.66034
# fold 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66912	valid_1's rmse: 3.70501
# [200]	training's rmse: 3.59281	valid_1's rmse: 3.67138
# [300]	training's rmse: 3.54481	valid_1's rmse: 3.66006
# [400]	training's rmse: 3.50864	valid_1's rmse: 3.65459
# [500]	training's rmse: 3.47962	valid_1's rmse: 3.64998
# [600]	training's rmse: 3.45437	valid_1's rmse: 3.64765
# [700]	training's rmse: 3.43249	valid_1's rmse: 3.646
# [800]	training's rmse: 3.41114	valid_1's rmse: 3.64539
# [900]	training's rmse: 3.39231	valid_1's rmse: 3.64491
# [1000]	training's rmse: 3.37485	valid_1's rmse: 3.64465
# [1100]	training's rmse: 3.35832	valid_1's rmse: 3.64399
# [1200]	training's rmse: 3.34237	valid_1's rmse: 3.64401
# [1300]	training's rmse: 3.32748	valid_1's rmse: 3.64434
# Early stopping, best iteration is:
# [1134]	training's rmse: 3.35274	valid_1's rmse: 3.64364
# CPU times: user 9min 6s, sys: 52.5 s, total: 9min 58s
# Wall time: 3min 19s

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = predictions
suffix = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
sub_df.to_csv(f"submission_{suffix}.csv", index=False)

# %% [markdown]
# - Score : 3.699
